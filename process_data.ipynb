# %%
import pandas as pd 
df = pd.read_csv('dehkhoda.csv')
df
# Out:
#                                            text
# 0                        بسم الله الرحمن الرحيم
# 1                                      کتابخانه
# 2                   اسلامی المعارف بنسیاد دایرة
# 3                                     روه ادبات
# 4                     به قلم گروهی از نویسندگان
# ...                                         ...
# 3704184  دهان برآرند برای به استهزاء تقلید کردن
# 3704185                     کسی )یادداشت مؤلف(.
# 3704186                                    1- .
# 3704187      ۲ – متن ایلاقی شاید غلط چاپی باشد.
# 3704188                                   پایان
#
# [3704189 rows x 1 columns]

# %%
for i in range(100):
    print(df['text'][i])
# Out:
# بسم الله الرحمن الرحيم
# کتابخانه
# اسلامی المعارف بنسیاد دایرة
# روه ادبات
# به قلم گروهی از نویسندگان
# زیر نظر
# دکتر محمد معين و دکتر سید جعفر شهیدی
# تا آذرماه (١٣٤٥
# داشام  شماره ثبت ۵٥٨٥۹
# مؤسسه لغت نامه دهخدا تاریخ
# 36
# â, , 1879-1955 4
# â ( ).  :  '
# ' . ,   , 1999.
# 16 . . 27.5 .
# 1.  .
# 3. , '.
# 2. ', , 1912-71.
# 4. .
# . 16:  964-03-9602-
# :  964-03-9617-6
# &
# شابک -۹۶۰۲-۰۳-۹۶۴ مقدمه(
# شابک ۶-۹۶۱۷-۰۳-۹۶۴ )دوره کامل(
# مقدمه لغت نامه دهخدا
# به قلم گروهی از نویسندگان
# ناشر مؤسسه انتشارات و چاپ دانشگاه تهران
# چاپ دوم از دوره جدید ۱۳۷۷
# تیراژ ۲۲۰۰۰ دوره
# قیمت دوره کامل ۷۵۰۰۰۰ ریال
# حروف چینی و صفحه بندی انتشارات روزنه
# لیتوگرافی سمن
# چاپ رسالت
# صحافی معین
# طراحی گرافیک علیرضا عابدینی
# خوش ئویس محمد احصائی
# این چاپ از لغت نامه دهخدا با همکاری انتشارات روزنه به انجام رسیده است.
# نشانی مؤسسه لغت نامه دهخدا:
# تهران، تجریش، ،خیابان ولی عصر، باغ ،فردوس، ایستگاه پسیان
# بسم الله الرحمن الرحيم
# یادداشتی بر چاپ دوم کامپیوتری
# ...
